# %%
import re

# https://regex101.com/

# %% [raw]
# re.search()
# re.match()
# re.findall()
# re.sub()

# %% [raw]
# re.search() and re.match()
# - result : None (if the pattern is not found)
#            <match object> (if the pattern is found)
#                     - from match object we extract the groups
#                             (actual text that got matched)

# %% [raw]
# re.findall()
# - result : None (if the pattern is not found)
#            tuple having all the matches (if the pattern is found)

# %% [raw]
# re.sub()     --->  substitute
# find a pattern and if found, then substitute

# %%
\d : [0-9]

# %%
\D : [^0-9]  # ^ : except whatever it is inside the bracket

# %%
\w : alphanumerics : [0-9 a-z A-Z]

# %%
re.search('[0-9|a-z|A-Z]', 'abc123')
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
text = 'A   labs'
#my text is starting with the capital A

# %%
re.sub('A.*labs','Automotive Labs','Alabs'.lower()) #if(condition,true value,else value)
# Out:
# 'alabs'

# %%
re.sub?

# %%
re.search('\w','abc123cskhbd')
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
pat_digit = '\d' # its a metacharacter that represents all digits : \d means [0-9]
string = "abc123"
mo1 = re.match(pat_digit,string) # --> no match
type(mo1)
# Out:
# NoneType

# %%
re.search(pat_digit,string) #--> match
# Out:
# <re.Match object; span=(3, 4), match='1'>

# %%
mo2 = re.match(pat_digit,'6abc123') # --> match
mo2
# Out:
# <re.Match object; span=(0, 1), match='6'>

# %%
re.findall(pat_digit,'abc123p647q2324r2426347')
# Out:
# ['1',
#  '2',
#  '3',
#  '6',
#  '4',
#  '7',
#  '2',
#  '3',
#  '2',
#  '4',
#  '2',
#  '4',
#  '2',
#  '6',
#  '3',
#  '4',
#  '7']

# %%
re.sub('\d',"*",'abc123p647q2324r2426347')
# re.sub('\d',"*",'abc123')
# Out:
# 'abc***p***q****r*******'

# %%
#

# %%
# The match function in re
# Matches for a pattern at the begining of a string

line1 = "this is PM modi" # no match
line2 = "Modi wins the election" # matches here
# if the pattern is 'modi'

# This is a literal form of regex
# r'string' --> raw text : text that can't be processed
matchObj = re.match( r'modi', line1, re.I)
# re.I : Case Insensitive matching

if matchObj:
    print ("Match found at the begining of the string!!")
    print ("matchObj.group() : ", matchObj.group())
else:
    print ("No match!!")
# Out:
# No match!!

# %%
matchObj = re.match( r'modi', line2, re.M|re.I)

if matchObj:
    print ("Match found at the begining of the string!!")
    print ("matchObj.group() : ", matchObj.group())
else:
    print ("No match!!")
# Out:
# Match found at the begining of the string!!
# matchObj.group() :  Modi

# %%
# The search function in re
# Matches for a pattern anywhere in a string

line1 = "this is PM modi"
line2 = "Modi wins the election"

matchObj = re.search( r'modi', line1, re.I)

if matchObj:
    print ("Match found in the string!!")
    print ("matchObj.group() has found : ", matchObj.group())
else:
    print ("No match!!")
matchObj
matchObj.group()
# Out:
# Match found in the string!!
# matchObj.group() has found :  modi
# 'modi'

# %%
line2 = "Modi wins the election"
pattern = r'modi' # raw string
matchObj = re.search( pattern, line2, re.I)

if matchObj:
    print ("Match found in the string!!")
    print ("matchObj.group() : ", matchObj.group())
else:
    print ("No match!!")
# Out:
# Match found in the string!!
# matchObj.group() :  Modi

# %%
# The or operator
pat1 = r'defence'
pat2 = r'defense'
pat3 = r'defen[s|c]e'

text1 = "We have a good defence system"
re.search(pat1,text1)
re.search(pat2,text1)
# re.search(pat3,text1)

# text2 = "US missile defense system is not as good as S400"
# re.search(pat1,text2)
# re.search(pat2,text2)
# re.search(pat3,text2)

# %%
# search for multiple patterns in one go in re
# we can use the | operator

# E.g. If modi or rahul is present, put a match

# line2 = "BJP wins the election. PM modi to take oath"
line2 = "BJP wins the election. PM Modi to take oath, Rahul flies to Pataya"
# line2 = "BJP wins the election. Rahul flies to Pataya"

searchObj = re.search( r'(modi|rahul)', line2, re.I)

if searchObj:
    print ("searchObj.group() : ", searchObj.group())
    print ("searchObj.groups() : ", searchObj.groups())
else:
    print ("No match!!")
# Out:
# searchObj.group() :  Modi
# searchObj.groups() :  ('Modi',)

# %%
l1 = 'US dept of defense spends $30bn in 2020'
l2 = 'ABCD gives the best defence system against network threats'
pat = r'defen[s|c]e'

mo_l1 = re.search(pat, l1)
mo_l1


mo_l2 = re.search(pat, l2)
mo_l2
# Out:
# <re.Match object; span=(20, 27), match='defence'>

# %%
searchObj = re.finditer( r'(modi|rahul)', line2, re.I)
searchObj

# %%
for match in searchObj : 
    print(match)
# Out:
# <re.Match object; span=(26, 30), match='Modi'>
# <re.Match object; span=(45, 50), match='Rahul'>

# %%
# Search and replace
text = "I drive Tuscon"

re.sub(string=text,pattern=r'Tuscon',repl='Hyundai Tuscon')
# Out:
# 'I drive Hyundai Tuscon'

# %% [markdown]
# ### Literals
#
# All the examples above are for literals. They are matching the exact words like that of a normal string match
#
# E.g.
#
# Expression : _python_
#
# Matches :
#
#     1. Python is interesting (re.I)
#     2. A python code has extention.py
#
# Doesn't Match :
#
#     1. This is a crossover
#     2. Java can be used as jython
#
# ___

# %%
pat = 'a' # litrally searching for "a"

res = re.match(pattern=pat, string="nasty")
# if there is a match, then match() and search() will create a match obj
res == None # no match
# Out:
# True

# %%
res = re.match(pattern=pat, string="aeroplane")
# if there is a match, then match() and search() will create a match obj
res
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
res = re.search(pattern=pat, string="nasty")
# 0,1,2,3,4

res

#(1,5) : 1,2,3,4
#(1,2) : 1
# Out:
# <_sre.SRE_Match object; span=(1, 2), match='a'>

# %%
res = re.search(pattern=pat, string="aeroplane")

res
# Out:
# <_sre.SRE_Match object; span=(0, 1), match='a'>

# %%
res = re.findall(pattern=pat, string="aeroplane")

res
# Out:
# ['a', 'a']

# %%
res = re.search(pattern=pat, string="nasty")

if res:
    print("found a match, at",res.start(),"and ends at",res.end()-1,"and the string is",res.group())
else:
    print("no match")
# Out:
# found a match, at 1 and ends at 1 and the string is a

# %% [markdown]
# ### Character Classes
#
# #### 1. Options in [ ]

# %%
text1 = "In my defence, I'll plead not guilty"
text2 = "US has best defense ships"

# %%
# text 1
text1 = "In my defence, I'll plead not guilty"
text2 = "US has best defense ships"
searchObj = re.search(pattern = r'defen[sc]e', string=text1, flags=re.M|re.I)

if searchObj:
    print ("searchObj.group() : ", searchObj.group())
else:
    print ("No match!!")
# Out:
# searchObj.group() :  defence

# %%
# text 2

searchObj = re.search( r'defen[sc]e', text2, re.M|re.I)

if searchObj:
    print ("searchObj.group() : ", searchObj.group())
else:
    print ("No match!!")
# Out:
# searchObj.group() :  defense

# %% [markdown]
# ---

# %%
# Eg. 2
# Task : match if the string begins with the following
# numbers 6,7,8 or 9
pat_num = r'[6789]\d{9}'
re.match(pat_num, '7323fsgsvsr')

# %%
re.match(pat_num, '7323342910')
# Out:
# <_sre.SRE_Match object; span=(0, 10), match='7323342910'>

# %%
re.match(pat_num, '3dfsjfjfjr') # no match

# %%
re.match(pat_num, 'a9dfsjfjfjr') # no match

# %% [markdown]
# #### 2. Digits [0-9] or `\d`

# %%
pat_digit = r'[0123456789]'
re.search(pat_digit,'abc123')
re.search(pat_digit,'abc')

# %%
text1 = "we are number 1 in this city"
searchObj = re.search( r'[0-9]', text1, re.M|re.I) 
# re.M : multiline character

if searchObj:
    print ("There is a match and the values is : ", searchObj.group())
else:
    print ("No match!!")
# Out:
# There is a match and the values is :  1

# %%
text1 = "we are numer 1 in this city"
searchObj = re.search( r'\d', text1, re.M|re.I)

if searchObj:
    print ("There is a match and the values is : ", searchObj.group())
else:
    print ("No match!!")
# Out:
# There is a match and the values is :  1

# %% [markdown]
# #### 3. Characters [a-z] and [A-Z]
#
# Matches characters in a string

# %%
formula1 = "23523523M23523"

searchObj = re.search( r'[a-z]', formula1) # we have removed the case sensitive filter

if searchObj:
    print ("searchObj.group() : ", searchObj.group())
else:
    print ("No match for case sensitive matching!!")
    
#---------------------------------------------------------------------

# A-Z
searchObj = re.search( r'[A-Z]', formula1) # we have removed the case sensitive filter

if searchObj:
    print ("searchObj.group() found when [A-Z] : ", searchObj.group())
else:
    print ("No match for case sensitive matching!!")
    
#
# Out:
# No match for case sensitive matching!!
# searchObj.group() found when [A-Z] :  M

# %% [markdown]
# #### 4. All alpha-numeric [a-zA-Z0-9]

# %%
formula2 = '454jkh5j5245jh5jkh45jk245h24'

searchObj = re.search( r'[a-zA-Z0-9]', formula2) 
if searchObj:
    print ("searchObj.group() : ", searchObj.group())
else:
    print ("No match!!")
# Out:
# searchObj.group() :  4

# %%
formula2 = '4fg**()_5h2A4'

re.findall( r'[a-zA-Z0-9]', formula2,re.I)
# Out:
# ['4', 'f', 'g', '5', 'h', '2', 'A', '4']

# %%
re.findall( r'[^a-zA-Z0-9]', formula2,re.I)
# Out:
# ['*', '*', '(', ')', '_']

# %%
formula2 = '@#$%*^#$$#&%$#$^&&#&'

searchObj = re.search( r'[a-zA-Z0-9]', formula2) 
if searchObj:
    print ("searchObj.group() : ", searchObj.group())
else:
    print ("No match!!")
# Out:
# No match!!

# %%
formula2 = '34a4643%^&434MM'

searchObj = re.findall( r'[a-zA-Z0-9]', formula2) 
if searchObj:
    print ("Matched Objects: ", searchObj)
    # please note, we have not used group() now
    # multiple matches are stored as a list
    # run type(searchObj) to verify
else:
    print ("No match!!")
# Out:
# Matched Objects:  ['3', '4', 'a', '4', '6', '4', '3', '4', '3', '4', 'M', 'M']

# %% [markdown]
# #### 5. Exclude the pattern
#
# We use a caret (^) to negate or exclude the pattern that is mentioned inside the []
#
# E.g. `[0-9]` matches all digits, which is also done by `\d`<p>
#      `[^0-9]` matches everything except digits also by `\D`

# %%
pat_not = r'[^0-9]'
re.match(pat_not,"7qwerty")

# %%
pat_yes = r'[0-9]'
re.match(pat_yes,"7qwerty")
# Out:
# <_sre.SRE_Match object; span=(0, 1), match='7'>

# %%
pat_not = r'\D'
re.match(pat_not,"7qwerty")

# %%
dig = '[0-9]'
re.findall(dig, "wegv3255n23n32&$%#%")
# Out:
# ['3', '2', '5', '5', '2', '3', '3', '2']

# %%
not_dig = '[^0-9]'
re.findall(not_dig, "wegv3255n23n32&$%#%")
# Out:
# ['w', 'e', 'g', 'v', 'n', 'n', '&', '$', '%', '#', '%']

# %% [markdown]
# ---

# %%
# digits
re.findall(pattern=r"[0-9]", string="ggner263436236%$&#$^&AJHDDJ")
# Out:
# ['2', '6', '3', '4', '3', '6', '2', '3', '6']

# %%
# lowercase alphabets
re.findall(pattern=r"[a-z]", string="ggner263436236%$&#$^&AJHDDJ")
# Out:
# ['g', 'g', 'n', 'e', 'r']

# %%
# uppercase alphabets
re.findall(pattern=r"[A-Z]", string="ggner263436236%$&#$^&AJHDDJ")
# Out:
# ['A', 'J', 'H', 'D', 'D', 'J']

# %%
# flag -> re.IGNORECASE or re.I

print("Lower case",re.findall(pattern=r"[a-z]", string="ggner263436236%$&#$^&AJHDDJ"))
print("all alphabets",re.findall(pattern=r"[a-zA-Z]", string="ggner263436236%$&#$^&AJHDDJ"))

# we can get all alphabets using only [a-z] along with re.I
print("all alphabets with lowercase charset but has a re.I flag",re.findall(pattern=r"[a-z]", string="ggner263436236%$&#$^&AJHDDJ",flags=re.I))
# Out:
# Lower case ['g', 'g', 'n', 'e', 'r']
# all alphabets ['g', 'g', 'n', 'e', 'r', 'A', 'J', 'H', 'D', 'D', 'J']
# all alphabets with lowercase charset but has a re.I flag ['g', 'g', 'n', 'e', 'r', 'A', 'J', 'H', 'D', 'D', 'J']

# %%
# all alphanumeric only
print(re.findall(pattern=r"[0-9a-zA-Z]", string="ggner263436236%$&#$^&AJHDDJ"))
# Out:
# ['g', 'g', 'n', 'e', 'r', '2', '6', '3', '4', '3', '6', '2', '3', '6', 'A', 'J', 'H', 'D', 'D', 'J']

# %%
# symbols only
print(re.findall(pattern=r"[^0-9a-zA-Z]", string="ggner263436236%$&#$^&AJHDDJ"))
# Out:
# ['%', '$', '&', '#', '$', '^', '&']

# %% [markdown]
# #### 6. Match any character except the newline : `.`

# %%
string = '36_%dsf.@!..\n.43%4MM'

pat = '.'
print(re.findall( pat, string) )
# Out:
# ['3', '6', '_', '%', 'd', 's', 'f', '.', '@', '!', '.', '.', '.', '4', '3', '%', '4', 'M', 'M']

# %%
string = '36_%@!..\n.43%4MM'

pat = '\.'
re.findall( pat, string)
# Out:
# ['.', '.', '.']

# %% [markdown]
# #### 7. `\s` matches a whitespace character  `[ \t\r\n\f]`

# %%
passwd = input("Enter password : ")

searchObj = re.search(r'\s',passwd)

if searchObj == None:
    print("Correct passwd")
else:
    print("Please don't use spaces")
# Out:
# Enter password : shd sjfh
# Please don't use spaces

# %%
formula2 = '34a46_~%@!..\n.43%^&434MM'

pat = r'\s'
searchObj = re.findall( r'\s', formula2) 

if searchObj:
    print ("Matched Objects: ", searchObj)
else:
    print ("No match!!")
# Out:
# Matched Objects:  ['3', '4', 'a', '4', '6', '_', '~', '%', '@', '!', '.', '.', '.', '4', '3', '%', '^', '&', '4', '3', '4', 'M', 'M']

# %% [markdown]
# #### 8. `\w` matches a single word character `[A-Za-z0-9]` and `\W` for `[^A-Za-z0-9]`

# %% [markdown]
# ---
# ### Quantifiers
#
# These symbols convey "how many times" a pattern has to be present inside a string. Whether it is present atleast once or multiple or exactly once or exactly n times etc.
#
# #### 1. Exactly one occurance or none at all `?`
#
# There will be a match if a pattern is present ___exactly once___ or __it is not present at all__

# %%
re.search(pattern="\d?", string='abcdef')
# Out:
# <re.Match object; span=(0, 0), match=''>

# %%
if re.search(pattern="\d?", string="abc8def"):
    print("match for pattern is found!")
else:
    print("no match")
# Out:
# match for pattern is found!

# %%
re.findall(pattern="\d?", string="abc899def")
# Out:
# ['', '', '', '8', '9', '9', '', '', '', '']

# %%
s1 = "9gag"
s2 = "marathon"

pat = r'[0-9]?'
# search for exactly one number or none at all
# Both s1 and s2 should match

searchObj = re.search( r'[0-9]?', s1) 

if searchObj:
    print ("Matched Objects for s1: ", searchObj.group())
else:
    print ("No match at all!!")

#---------------------------------------------------------
searchObj = re.search( r'[0-9]?', s2) 

if searchObj:
    print("-----------------------------------------------")
    print ("Matched Objects for s2: ", searchObj.group())
    print("Not going into unmatched state")
else:
    print ("No match at all!!")
# Out:
# Matched Objects for s1:  9
# -----------------------------------------------
# Matched Objects for s2:
# Not going into unmatched state

# %% [markdown]
# #### 2. Atleast one occurance `+`
#
# There will be a match if a pattern is present ___at least once___

# %%
if re.search(pattern="\d+", string="abcdef"):
    print("match for pattern is found!")
else:
    print("no match")
# Out:
# no match

# %%
if re.search(pattern="\d+", string="abcde9f"):
    print("match for pattern is found!")
else:
    print("no match")
# Out:
# match for pattern is found!

# %%
s1 = "9gag"
s2 = "marathon"

searchObj = re.match( r'[0-9]+', s1) 

if searchObj:
    print ("Matched Objects for s1: ", searchObj.group())
else:
    print ("No match at all!!")

#---------------------------------------------------------
searchObj = re.match( r'[0-9]+', s2) 
print("-----------------------------------------------")


if searchObj:
    print ("Matched Objects for s2: ", searchObj.group())
else:
    print ("No match at all for s2!!")
# Out:
# Matched Objects for s1:  9
# -----------------------------------------------
# No match at all for s2!!

# %% [markdown]
# #### 3. Many occurances or none at all `*`
#
# There will be a match if a pattern is present ___any number of times___ or __none at all__

# %%
if re.search(pattern="\d*", string="abcdef"):
    print("match for pattern is found!")
else:
    print("no match")
# Out:
# match for pattern is found!

# %%
if re.search(pattern="\d*", string="abcde9f"):
    print("match for pattern is found!")
else:
    print("no match")
# Out:
# match for pattern is found!

# %%
s1 = "999gag"
s2 = "marathon"

# search for exactly one number or none at all
# Both s1 and s2 should match

searchObj = re.match( r'[0-9]*', s1) 

if searchObj:
    print ("Matched Objects for s1: ", searchObj.group())
else:
    print ("No match at all!!")

#---------------------------------------------------------
searchObj = re.match( r'[0-9]*', s2) 
print("-----------------------------------------------")


if searchObj:
    print ("Matched Objects for s2: ", searchObj.group())
else:
    print ("No match at all for s2!!")
# Out:
# Matched Objects for s1:  999
# -----------------------------------------------
# Matched Objects for s2:

# %% [markdown]
# #### 4. Minimum n times and maximum m times `{n,m}`
#
# There will be a match if a pattern is present ___n number of times___ and maximum __m times__
#
# - If n is not given and m is given, then it's min = 0 and max = m
# - If m is not given and n is given, then it's min = n and max = any number of times

# %%
#Task : find numbers begining with 6,7,8 or 9 followed 
#       by 9 digits
pat = "[6-9]\d{9}"

re.findall(pat, string="call us at 9876543210")
# Out:
# ['9876543210']

# %%
#Task : find numbers begining with 6,7,8 or 9 followed 
#       by 9 digits
pat = "[6-9]\d{9}"

re.findall(pat, string="call us at 9876543210345")
# Out:
# ['9876543210']

# %%
s1 = "998989gag"
s2 = "99marathon"

# search for exactly one number or none at all
# Both s1 and s2 should match

searchObj = re.match( r'[0-9]{3,6}', s1) 

if searchObj:
    print ("Matched Objects for s1: ", searchObj.group())
else:
    print ("No match at all!!")

#---------------------------------------------------------
searchObj = re.match( r'[0-9]{3,6}', s2) 

if searchObj:
    print ("Matched Objects for s2: ", searchObj.group())
else:
    print ("No match at all!!")

#---------------------------------------------------------

# %% [markdown]
# ---
# ### Anchors
#
# They are used to specify the position where we need to get a match. Like, start of the string, end of the string, word boundaries etc

# %%
#Task : find numbers begining with 6,7,8 or 9 followed 
#       by 9 digits
pat = "^[6-9]\d{9}$"

re.findall(pat, string="9876543210345")
# Out:
# []

# %%
#Task : find numbers begining with 6,7,8 or 9 followed 
#       by 9 digits
pat = "^[6-9]\d{9}$"

re.findall(pat, string="9876543210")
# Out:
# ['9876543210']

# %% [markdown]
# #### 1. `^` : start of the string
#
# This is differnet from caret when used inside a bracket `[^]`.

# %%
# this is different from [^] 

# Aim : to search for the pattern "python" in the start of the string

s1 = "we are learning python for data science"
s2 = "python is fun"

searchObj = re.search( r'^python', s1) 
if searchObj:
    print ("Matched Objects for s1: ", searchObj.group())
else:
    print ("No match at all!!")

#---------------------------------------------------------
searchObj = re.search( r'^python', s2) 
print("-----------------------------------------------")
if searchObj:
    print ("Matched Objects for s2: ", searchObj.group())
else:
    print ("No match at all for s2!!")

# %% [markdown]
# #### 2. `$` : end of the string

# %%
# Aim : to search for the pattern "python" in the start of the string

s1 = "we are learning python for data science"
s2 = "python is fun"
s3 = "I love Python"

searchObj = re.search( r'python$', s1, re.I) 
if searchObj:
    print ("Matched Objects for s1: ", searchObj.group())
else:
    print ("No match at all!!")

#---------------------------------------------------------
searchObj = re.search( r'python$', s2, re.I) 
print("-----------------------------------------------")
if searchObj:
    print ("Matched Objects for s2: ", searchObj.group())
else:
    print ("No match at all for s2!!")

#---------------------------------------------------------
searchObj = re.search( r'python$', s3, re.I) 
print("-----------------------------------------------")
if searchObj:
    print ("Matched Objects for s3: ", searchObj.group())
else:
    print ("No match at all for s3!!")

# %%
s1 = "we are learning python"
s2 = "python is fun"

searchObj = re.findall( r'python$', s1) 
if searchObj:
    print ("Matched Objects for s1: ", searchObj)
else:
    print ("No match at all!!")

#---------------------------------------------------------
searchObj = re.match( r'python$', s2) 
print("-----------------------------------------------")
if searchObj:
    print ("Matched Objects for s2: ", searchObj.group())
else:
    print ("No match!!")

# %% [markdown]
# #### 3. `\bxxx\b` : Exact pattern within a string.
#
# This would match the exact pattern but won't match for strings that contain the given patten along with something else

# %%
s1 = "This is a good vapo rub"
s2 = "Malaysia has largest rubber production"
s3 = "Brabbbruby is an easy language"

searchObj = re.findall( r'rub', s1) 
if searchObj:
    print ("Matched Objects for s1: ", searchObj)
else:
    print ("No match at all!!")

#---------------------------------------------------------
searchObj = re.findall(r'rub', s2) 
print("-----------------------------------------------")
if searchObj:
    print ("Matched Objects for s2: ", searchObj)
else:
    print ("No match!!")

#---------------------------------------------------------
searchObj = re.findall(r'rub', s3) 
print("-----------------------------------------------")
if searchObj:
    print ("Matched Objects for s3: ", searchObj)
else:
    print ("No match!!")

# %% [markdown]
# #### 4. `\bxxx\B` : Sting containing the pattern but not the exact pattern
#
# This is the exact opposite of the above boundary patterm. This would match for the strings that contain the given patten along with something else but will __never__ match if the patten is present alone

# %%
s1 = "rub"
s2 = "rubber"
s3 = "ruby"

searchObj = re.findall( r'\brub\B', s1) 
if searchObj:
    print ("Matched Objects for s1: ", searchObj)
else:
    print ("No match at all!!")

#---------------------------------------------------------
searchObj = re.match(r'\brub\B', s2) 
print("-----------------------------------------------")
if searchObj:
    print ("Matched Objects for s2: ", searchObj.group())
else:
    print ("No match!!")

#---------------------------------------------------------
searchObj = re.match(r'\brub\B', s3) 
print("-----------------------------------------------")
if searchObj:
    print ("Matched Objects for s3: ", searchObj.group())
else:
    print ("No match!!")

# %%
name1 = "Manuj Singla"
name2 = "Arpit Dqwr"

searchObj = re.search(r'^M([a-zA-Z]*)(\s)+S([a-zA-Z]*)', name1) 

print("-----------------------------------------------")
if searchObj:
    print ("Matched Objects for s3: ", searchObj.group())
else:
    print ("No match!!")
    
searchObj = re.search(r'^M([a-zA-Z]*)(\s)+S([a-zA-Z]*)', name2) 

print("-----------------------------------------------")
if searchObj:
    print ("Matched Objects for s3: ", searchObj.group())
else:
    print ("No match!!")

# %% [raw]
# https://regex101.com/

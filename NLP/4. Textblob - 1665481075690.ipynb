# %%
text = 'the food was excellent but the service was pathetic.'

# %%
# Change language if required
from textblob import TextBlob

# %%
tb = TextBlob(text)

# %%
tb.sentiment.polarity
# Out:
# 0.0
